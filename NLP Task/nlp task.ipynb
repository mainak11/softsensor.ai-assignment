# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import re
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize

# %%
organ_names=[]
content__=[]
url='https://www.pathologyoutlines.com/'
response=requests.get(url)
soup=BeautifulSoup(response.text,"html.parser")
content=soup.find('div',{"class":"home_content clearfix"})
links=content.find_all('a')
for i in links:
    #print(i.get('href'))
    organ_names.append(i.text)
    link2=i.get('href')
    response=requests.get(link2)
    soup=BeautifulSoup(response.text,"html.parser")
    content=soup.find_all('div',{"class":"page_content"})
    content_=[]
    for i in range(len(content)):
        content1=content[i].find_all('div',{"class":"toc_section toc_links"})
    #print(len(content))
        for i in range(len(content1)):
        #print(i)
            content2=content1[i].find_all('span',{"class":"toc_subsection toc_links"})
            for i in range(len(content2)):
                content3=content2[i].find_all('a')
                
                for i in range(len(content3)):
                    #print(content3[i].text)
                    content_.append(content3[i].text)
    content__.append(content_)

# %%
df=pd.DataFrame(list(zip(organ_names,content__)),columns = ['Organ Name', 'Content'])

# %%
dictionary=df.to_dict()

# %%
print(dictionary)
# Out:
# {'Organ Name': {0: 'Adrenal gland & paraganglia', 1: 'Anus & perianal', 2: 'Appendix', 3: 'Autopsy & forensics', 4: 'Bladder, ureter & renal pelvis', 5: 'Bone & joints', 6: 'Bone marrow neoplastic', 7: 'Bone marrow nonneoplastic', 8: 'Breast', 9: 'Cervix', 10: 'Chemistry, toxicology & urinalysis', 11: 'CNS nontumor', 12: 'CNS tumor', 13: 'Coagulation', 14: 'Colon', 15: 'COVID-19', 16: 'Cytopathology', 17: 'Ear', 18: 'Esophagus', 19: 'Eye', 20: 'Fallopian tubes & broad ligament', 21: 'Gallbladder & extrahep bile ducts', 22: 'Heart', 23: 'Hematology', 24: 'Informatics, digital & computational', 25: 'Kidney nontumor', 26: 'Kidney tumor', 27: 'Lab admin & management', 28: 'Larynx, hypopharynx & trachea', 29: 'Liver & intrahepatic bile ducts', 30: 'Lung', 31: 'Lymph nodes & spleen', 32: 'Lymphoma & related disorders', 33: 'Mandible & maxilla', 34: 'Mediastinum', 35: 'Microbiology & parasitology', 36: 'Molecular markers', 37: 'Muscle & nerve nontumor', 38: 'Nasal cavity & nasopharynx', 39: 'Oral cavity & oropharynx', 40: 'Ovary', 41: 'Pancreas', 42: 'Penis & scrotum', 43: 'Placenta', 44: 'Pleura & peritoneum', 45: 'Prostate gland & seminal vesicles', 46: 'Salivary glands', 47: 'Skin melanocytic tumor', 48: 'Skin nonmelanocytic tumor', 49: 'Skin nontumor', 50: 'Small intestine & ampulla', 51: 'Soft tissue', 52: 'Staging', 53: 'Stains & CD markers', 54: 'Stomach', 55: 'Testis & paratestis', 56: 'Thyroid & parathyroid', 57: 'Transfusion medicine', 58: 'Uterus', 59: 'Vulva, vagina & female urethra'}, 'Content': {0: ['anatomy & embryology-adrenal', 'anatomy-paraganglia', 'books', 'features to report-adrenal cortical carcinoma', 'features to report-pheochromocytoma / paraganglioma', 'histology-adrenal cortex', 'histology-adrenal medulla', 'staging-adrenal cortical carcinoma', 'staging-neuroblastic tumors', 'staging-pheochromocytoma and paraganglioma', 'WHO classification', 'primary adrenal insufficiency', 'secondary adrenal insufficiency', 'Addison disease', 'adrenal hypoplasia', 'adrenoleukodystrophy', 'autoimmune adrenalitis', 'Waterhouse-Friderichsen syndrome', 'acquired adrenal cortical hyperplasia', 'adrenal cytomegaly', 'Beckwith-Wiedemann syndrome', 'congenital adrenal hyperplasia', 'Cushing syndrome', 'hyperaldosteronism', 'macronodular hyperplasia', 'macronodular hyperplasia with marked adrenal enlargement', 'micronodular hyperplasia', 'pigmented adrenal cortical hyperplasia', 'cysts (endothelial, pseudocyst, parasitic)', 'ectopic adrenal tissue', 'focal adrenalitis', 'ovarian thecal metaplasia', 'adenoma', 'aldosterone producing', 'corticomedullary mixed tumor', 'oncocytoma', 'adrenal cortical carcinoma', 'myxoid variant', 'oncocytic variant', 'sarcomatoid variant', 'pheochromocytoma', 'paraganglioma', 'composite pheochromocytoma', 'hyperplasia-medulla', 'hyperplasia-paraganglia', 'neuroblastic tumors overview', 'ganglioneuroma', 'ganglioneuroblastoma', 'ganglioneuroblastoma, intermixed variant', 'ganglioneuroblastoma, nodular variant', 'neuroblastoma', 'adenomatoid tumor', 'hemangioma', 'lymphangioma', 'lymphoma', 'metastases', 'myelolipoma', 'plasmacytoma'], 1: ['anatomy & histology', 'books', 'grossing & features to report', 'staging', 'WHO classification', 'granuloma inguinale', 'HSV related hypertrophy in HIV+ patients', 'lymphogranuloma venereum', "Crohn's disease", 'fissure', 'fistula', 'hemorrhoids', 'hypertrophied papillae', 'inflammatory cloacogenic polyp', 'tailgut cyst', 'Buschke-Löwenstein tumor', 'condyloma acuminatum', 'squamous dysplasia', 'carcinoma overview', 'adenocarcinoma', 'basal cell carcinoma', 'Paget disease', 'small cell (neuroendocrine) carcinoma', 'squamous cell carcinoma', 'verrucous carcinoma', 'granular cell tumor', 'melanoma'], 2: ['anatomy', 'books', 'features to report & grossing', 'staging-carcinoma', 'staging-neuroendocrine tumors', 'WHO classification', 'cystic fibrosis', 'adenovirus & measles', 'acute appendicitis', 'CMV appendicitis (pending)', 'Enterobius vermicularis', 'granulomatous appe ...
