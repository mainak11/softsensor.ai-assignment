# %%
#!pip install openslide-python
#!pip install slideio

#!pip install opencv-python
# Out:
# Collecting openslide-python
#   Using cached openslide_python-1.2.0-cp39-cp39-win_amd64.whl (19 kB)
# Requirement already satisfied: Pillow in c:\users\mainak\anaconda3\lib\site-packages (from openslide-python) (8.4.0)
# Installing collected packages: openslide-python
# Successfully installed openslide-python-1.2.0

# %% [markdown]
# ## import libraries

# %%
from openslide import open_slide
import openslide
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
import cv2
import os

# %% [markdown]
# ## import the slide image

# %%
slide = open_slide("Normal Lymphnode.svs")

slide_props = slide.properties
print(slide_props)
# Out:
# <_PropertyMap {'aperio.AppMag': '40', 'aperio.MPP': '0.241158', 'openslide.comment': 'Aperio Image Library v10.2.24\r\r\n35817x38693 [0,0 35817x38693] [256x256] JPEG/YCbCr Q = 75|AppMag = 40|MPP = 0.241158', 'openslide.level-count': '3', 'openslide.level[0].downsample': '1', 'openslide.level[0].height': '38693', 'openslide.level[0].tile-height': '256', 'openslide.level[0].tile-width': '256', 'openslide.level[0].width': '35817', 'openslide.level[1].downsample': '4.0001075312368233', 'openslide.level[1].height': '9673', 'openslide.level[1].tile-height': '256', 'openslide.level[1].tile-width': '256', 'openslide.level[1].width': '8954', 'openslide.level[2].downsample': '16.003044636184825', 'openslide.level[2].height': '2418', 'openslide.level[2].tile-height': '256', 'openslide.level[2].tile-width': '256', 'openslide.level[2].width': '2238', 'openslide.mpp-x': '0.24115800000000001', 'openslide.mpp-y': '0.24115800000000001', 'openslide.objective-power': '40', 'openslide.quickhash-1': '30d7e637724f200c49ec80f387fa9b541ae5708245dca90cea96088d86872693', 'openslide.vendor': 'aperio', 'tiff.ImageDescription': 'Aperio Image Library v10.2.24\r\r\n35817x38693 [0,0 35817x38693] [256x256] JPEG/YCbCr Q = 75|AppMag = 40|MPP = 0.241158', 'tiff.ResolutionUnit': 'inch'}>

# %% [markdown]
# ## visualize the image preview

# %%
slide_thumb_600 = slide.get_thumbnail(size=(600, 600))
#slide_thumb_600.show()

slide_thumb_600_np = np.array(slide_thumb_600)
plt.figure(figsize=(8,8))
plt.imshow(slide_thumb_600_np)

# %% [markdown]
# ## breaking slide into tiles

# %%
from openslide.deepzoom import DeepZoomGenerator

#Generate object for tiles using the DeepZoomGenerator
tiles = DeepZoomGenerator(slide, tile_size=256, overlap=0, limit_bounds=False)

# %%
print("The number of levels in the tiles object are: ", tiles.level_count)

print("The dimensions of data in each level are: ", tiles.level_dimensions)

#Total number of tiles in the tiles object
print("Total number of tiles = : ", tiles.tile_count)
# Out:
# The number of levels in the tiles object are:  17
# The dimensions of data in each level are:  ((1, 1), (2, 2), (3, 3), (5, 5), (9, 10), (18, 19), (35, 38), (70, 76), (140, 152), (280, 303), (560, 605), (1120, 1210), (2239, 2419), (4478, 4837), (8955, 9674), (17909, 19347), (35817, 38693))
# Total number of tiles = :  28409

# %%
cols, rows = tiles.level_tiles[16]

# %%
tile_dir = "images/Normal Lymphnode images/"

# %% [markdown]
# ## saving tiles in local folder

# %%
for row in range(rows):
    for col in range(cols):
        tile_name = os.path.join(tile_dir, '%d_%d' % (col, row))
        print("Now saving tile with title: ", tile_name)
        temp_tile = tiles.get_tile(16, (col, row))
        temp_tile_RGB = temp_tile.convert('RGB')
        temp_tile_np = np.array(temp_tile_RGB)
        plt.imsave(tile_name + ".png", temp_tile_np)
# Out:
# Now saving tile with title:  images/Normal Lymphnode images/0_0
# Now saving tile with title:  images/Normal Lymphnode images/1_0
# Now saving tile with title:  images/Normal Lymphnode images/2_0
# Now saving tile with title:  images/Normal Lymphnode images/3_0
# Now saving tile with title:  images/Normal Lymphnode images/4_0
# Now saving tile with title:  images/Normal Lymphnode images/5_0
# Now saving tile with title:  images/Normal Lymphnode images/6_0
# Now saving tile with title:  images/Normal Lymphnode images/7_0
# Now saving tile with title:  images/Normal Lymphnode images/8_0
# Now saving tile with title:  images/Normal Lymphnode images/9_0
# Now saving tile with title:  images/Normal Lymphnode images/10_0
# Now saving tile with title:  images/Normal Lymphnode images/11_0
# Now saving tile with title:  images/Normal Lymphnode images/12_0
# Now saving tile with title:  images/Normal Lymphnode images/13_0
# Now saving tile with title:  images/Normal Lymphnode images/14_0
# Now saving tile with title:  images/Normal Lymphnode images/15_0
# Now saving tile with title:  images/Normal Lymphnode images/16_0
# Now saving tile with title:  images/Normal Lymphnode images/17_0
# Now saving tile with title:  images/Normal Lymphnode images/18_0
# Now saving tile with title:  images/Normal Lymphnode images/19_0
# Now saving tile with title:  images/Normal Lymphnode images/20_0
# Now saving tile with title:  images/Normal Lymphnode images/21_0
# Now saving tile with title:  images/Normal Lymphnode images/22_0
# Now saving tile with title:  images/Normal Lymphnode images/23_0
# Now saving tile with title:  images/Normal Lymphnode images/24_0
# Now saving tile with title:  images/Normal Lymphnode images/25_0
# Now saving tile with title:  images/Normal Lymphnode images/26_0
# Now saving tile with title:  images/Normal Lymphnode images/27_0
# Now saving tile with title:  images/Normal Lymphnode images/28_0
# Now saving tile with title:  images/Normal Lymphnode images/29_0
# Now saving tile with title:  images/Normal Lymphnode images/30_0
# Now saving tile with title:  images/Normal Lymphnode images/31_0
# Now saving tile with title:  images/Normal Lymphnode images/32_0
# Now saving tile with title:  images/Normal Lymphnode images/33_0
# Now saving tile with title:  images/Normal Lymphnode images/34_0
# Now saving tile with title:  images/Normal Lymphnode images/35_0
# Now saving tile with title:  images/Normal Lymphnode images/36_0
# Now saving tile with title:  images/Normal Lymphnode images/37_0
# Now saving tile with title:  images/Normal Lymphnode images/38_0
# Now saving tile with title:  images/Normal Lymphnode images/39_0
# Now saving tile with title:  images/Normal Lymphnode images/40_0
# Now saving tile with title:  images/Normal Lymphnode images/41_0
# Now saving tile with title:  images/Normal Lymphnode images/42_0
# Now saving tile with title:  images/Normal Lymphnode images/43_0
# Now saving tile with title:  images/Normal Lymphnode images/44_0
# Now saving tile with title:  images/Normal Lymphnode images/45_0
# Now saving tile with title:  images/Normal Lymphnode images/46_0
# Now saving tile with title:  images/Normal Lymphnode images/47_0
# Now saving tile with title:  images/Normal Lymphnode images/48_0
# Now saving tile with title:  images/Normal Lymphnode images/49_0
# Now saving tile with title:  images/Normal Lymphnode images/50_0
# Now saving tile with title:  images/Normal Lymphnode images/51_0
# Now saving tile with title:  images/Normal Lymphnode images/52_0
# Now saving tile with title:  images/Normal Lymphnode images/53_0
# Now saving tile with title:  images/Normal Lymphnode images/54_0
# Now saving tile with title:  images/Normal Lymphnode images/55_0
# Now saving tile with title:  images/Normal Lymphnode images/56_0
# Now saving tile with title:  images/Normal Lymphnode images/57_0
# Now saving tile with title:  images/Normal Lymphnode images/58_0
# Now saving tile with title:  images/Normal Lymphnode images/59_0
# Now saving tile with title:  images/Normal Lymphnode images/60_0
# Now saving tile with title:  images/Normal Lymphnode images/61_0
# Now saving tile with title:  images/Normal Lymphnode images/62_0
# Now saving tile with title:  images/Normal Lymphnode images/63_0
# Now saving tile with title:  images/Normal Lymphnode images/64_0
# Now saving tile with title:  images/Normal Lymphnode images/65_0
# Now saving tile with title:  images/Normal Lymphnode images/66_0
# Now saving tile with title:  images/Normal Lymphnode images/67_0
# Now saving tile with title:  images/Normal Lymphnode images/68_0
# Now saving tile with title:  images/Normal Lymphnode images/69_0
# Now saving tile with title:  images/Normal Lymphnode images/70_0
# Now saving tile with title:  images/Normal Lymphnode images/71_0
# Now saving tile with title:  images/Normal Lymphnode images/72_0
# Now saving tile with title:  images/Normal Lymphnode images/73_0
# Now saving tile with title:  images/Normal Lymphnode images/74_0
# Now saving tile with title:  images/Normal Lymphnode images/75_0
# Now saving tile with title:  images/Normal Lymphnode images/76_0
# Now saving tile with title:  images/Normal Lymphnode images/77_0
# Now saving tile with title:  images/Normal Lymphnode images/78_0
# Now saving tile with title:  images/Normal Lymphnode images/79_0
# Now saving tile with title:  images/Normal Lymphnode images/80_0
# Now saving tile with title:  images/Normal Lymphnode images/81_0
# Now saving tile with title:  images/Normal Lymphnode images/82_0
# Now saving tile with title:  images/Normal Lymphnode images/83_0
# Now saving tile with title:  images/Normal Lymphnode images/84_0
# Now saving tile with title:  images/Normal Lymphnode images/85_0
# Now saving tile with title:  images/Normal Lymphnode images/86_0
# Now saving tile with title:  images/Normal Lymphnode images/87_0
# Now saving tile with title:  images/Normal Lymphnode images/88_0
# Now saving tile with title:  images/Normal Lymphnode images/89_0
# Now saving tile with title:  images/Normal Lymphnode images/90_0
# Now saving tile with title:  images/Normal Lymphnode images/91_0
# Now saving tile with title:  images/Normal Lymphnode images/92_0
# Now saving tile with title:  images/Normal Lymphnode images/93_0
# Now saving tile with title:  images/Normal Lymphnode images/94_0
# Now saving tile with title:  images/Normal Lymphnode images/95_0
# Now saving tile with title:  images/Normal Lymphnode images/96_0
# Now saving tile with title:  images/Normal Lymphnode images/97_0
# Now saving tile with title:  images/Normal Lymphnode images/98_0
# Now saving tile with title:  images/Normal Lymphnode images/99_0
# Now saving tile with title:  images/Normal Lymphnode images/100_0
# Now saving tile with title:  images/Normal Lymphnode images/101_0
# Now saving tile with title:  images/Normal Lymphnode images/102_0
# Now saving tile with title:  images/Normal Lymphnode images/103_0
# Now saving tile with title:  images/Normal Lymphnode images/104_0
# Now saving tile with title:  images/Normal Lymphnode images/105_0
# Now saving tile with title:  images/Normal Lymphnode images/106_0
# Now saving tile with title:  images/Normal Lymphnode images/107_0
# Now saving tile with title:  images/Normal Lymphnode images/108_0
# Now saving tile with title:  images/Normal Lymphnode images/109_0
# Now saving tile with title:  images/Normal Lymphnode images/110_0
# Now saving tile with title:  images/Normal Lymphnode images/111_0
# Now saving tile with title:  images/Normal Lymphnode images/112_0
# Now saving tile with title:  images/Normal Lymphnode images/113_0
# Now saving tile with title:  images/Normal Lymphnode images/114_0
# Now saving tile with title:  images/Normal Lymphnode images/115_0
# Now saving tile with title:  images/Normal Lymphnode images/116_0
# Now saving tile with title:  images/Normal Lymphnode images/117_0
# Now saving tile with title:  images/Normal Lymphnode images/118_0
# Now saving tile with title:  images/Normal Lymphnode images/119_0
# Now saving tile with title:  images/Normal Lymphnode images/120_0
# Now saving tile with title:  images/Normal Lymphnode images/121_0
# Now saving tile with title:  images/Normal Lymphnode images/122_0
# Now saving tile with title:  images/Normal Lymphnode images/123_0
# Now saving tile with title:  images/Normal Lymphnode images/124_0
# Now saving tile with title:  images/Normal Lymphnode images/125_0
# Now saving tile with title:  images/Normal Lymphnode images/126_0
# Now saving tile with title:  images/Normal Lymphnode images/127_0
# Now saving tile with title:  images/Normal Lymphnode images/128_0
# Now saving tile with title:  images/Normal Lymphnode images/129_0
# Now saving tile with title:  images/Normal Lymphnode images/130_0
# Now saving tile with title:  images/Normal Lymphnode images/131_0
# Now saving tile with title:  images/Normal Lymphnode images/132_0
# Now saving tile with title:  images/Normal Lymphnode images/133_0
# Now saving tile with title:  images/Normal Lymphnode images/134_0
# Now saving tile with title:  images/Normal Lymphnode images/135_0
# Now saving tile with title:  images/Normal Lymphnode images/136_0
# Now saving tile with title:  images/Normal Lymphnode images/137_0
# Now saving tile with title:  images/Normal Lymphnode images/138_0
# Now saving tile with title:  images/Normal Lymphnode images/139_0
# Now saving tile with title:  images/Normal Lymphnode images/0_1
# Now saving tile with title:  images/Normal Lymphnode images/1_1
# Now saving tile with title:  images/Normal Lymphnode images/2_1
# Now saving tile with title:  images/Normal Lymphnode images/3_1
# Now saving tile with title:  images/Normal Lymphnode images/4_1
# Now saving tile with title:  images/Normal Lymphnode images/5_1
# Now saving tile with title:  images/Normal Lymphnode images/6_1
# Now saving tile with title:  images/Normal Lymphnode images/7_1
# Now saving tile with title:  images/Normal Lymphnode images/8_1
# Now saving tile with title:  images/Normal Lymphnode images/9_1
# Now saving tile with title:  images/Normal Lymphnode images/10_1
# Now saving tile with title:  images/Normal Lymphnode images/11_1
# Now saving tile with title:  images/Normal Lymphnode images/12_1
# Now saving tile with title:  images/Normal Lymphnode images/13_1
# Now saving tile with title:  images/Normal Lymphnode images/14_1
# Now saving tile with title:  images/Normal Lymphnode images/15_1
# Now saving tile with title:  images/Normal Lymphnode images/16_1
# Now saving tile with title:  images/Normal Lymphnode images/17_1
# Now saving tile with title:  images/Normal Lymphnode images/18_1
# Now saving tile with title:  images/Normal Lymphnode images/19_1
# Now saving tile with title:  images/Normal Lymphnode images/20_1
# Now saving tile with title:  images/Normal Lymphnode images/21_1
# Now saving tile with title:  images/Normal Lymphnode images/22_1
# Now saving tile with title:  images/Normal Lymphnode images/23_1
# Now saving tile with title:  images/Normal Lymphnode images/24_1
# Now saving tile with title:  images/Normal Lymphnode images/25_1
# Now saving tile with title:  images/Normal Lymphnode images/26_1
# Now saving tile with title:  images/Normal Lymphnode images/27_1
# Now saving tile with title:  images/Normal Lymphnode images/28_1
# Now saving tile with title:  images/Normal Lymphnode images/29_1
# Now saving tile with title:  images/Normal Lymphnode images/30_1
# Now saving tile with title:  images/Normal Lymphnode images/31_1
# Now saving tile with title:  images/Normal Lymphnode images/32_1
# Now saving tile with title:  images/Normal Lymphnode images/33_1
# Now saving tile with title:  images/Normal Lymphnode images/34_1
# Now saving tile with title:  images/Normal Lymphnode images/35_1
# Now saving tile with title:  images/Normal Lymphnode images/36_1
# Now saving tile with title:  images/Normal Lymphnode images/37_1
# Now saving tile with title:  images/Normal Lymphnode images/38_1
# Now saving tile with title:  images/Normal Lymphnode images/39_1
# Now saving tile with title:  images/Normal Lymphnode images/40_1
# Now saving tile with title:  images/Normal Lymphnode images/41_1
# Now saving tile with title:  images/Normal Lymphnode images/42_1
# Now saving tile with title:  images/Normal Lymphnode images/43_1
# Now saving tile with title:  images/Normal Lymphnode images/44_1
# Now saving tile with title:  images/Normal Lymphnode images/45_1
# Now saving tile with title:  images/Normal Lymphnode images/46_1
# Now saving tile with title:  images/Normal Lymphnode images/47_1
# Now saving tile with title:  images/Normal Lymphnode images/48_1
# Now saving tile with title:  images/Normal Lymphnode images/49_1
# Now saving tile with title:  images/Normal Lymphnode images/50_1
# Now saving tile with title:  images/Normal Lymphnode images/51_1
# Now saving tile with title:  images/Normal Lymphnode images/52_1
# Now saving tile with title:  images/Normal Lymphnode images/53_1
# Now saving tile with title:  images/Normal Lymphnode images/54_1
# Now saving tile with title:  images/Normal Lymphnode images/55_1
# Now saving tile with title:  images/Normal Lymphnode images/56_1
# Now saving tile with title:  images/Normal Lymphnode images/57_1
# Now saving tile with title:  images/Normal Lymphnode images/58_1
# Now saving tile with title:  images/Normal Lymphnode images/59_1
# Now saving tile with title:  images/Normal Lymphnode images/60_1
# Now saving tile with title:  images/Normal Lymphnode images/61_1
# Now saving tile with title:  images/Normal Lymphnode images/62_1
# Now saving tile with title:  images/Normal Lymphnode images/63_1
# Now saving tile with title:  images/Normal Lymphnode images/64_1
# Now saving tile with title:  images/Normal Lymphnode images/65_1
# Now saving tile with title:  images/Normal Lymphnode images/66_1
# Now saving tile with title:  images/Normal Lymphnode images/67_1
# Now saving tile with title:  images/Normal Lymphnode images/68_1
# Now saving tile with title:  images/Normal Lymphnode images/69_1
# Now saving tile with title:  images/Normal Lymphnode images/70_1
# Now saving tile with title:  images/Normal Lymphnode images/71_1
# Now saving tile with title:  images/Normal Lymphnode images/72_1
# Now saving tile with title:  images/Normal Lymphnode images/73_1
# Now saving tile with title:  images/Normal Lymphnode images/74_1
# Now saving tile with title:  images/Normal Lymphnode images/75_1
# Now saving tile with title:  images/Normal Lymphnode images/76_1
# Now saving tile with title:  images/Normal Lymphnode images/77_1
# Now saving tile with title:  images/Normal Lymphnode images/78_1
# Now saving tile with title:  images/Normal Lymphnode images/79_1
# Now saving tile with title:  images/Normal Lymphnode images/80_1
# Now saving tile with title:  images/Normal Lymphnode images/81_1
# Now saving tile with title:  images/Normal Lymphnode images/82_1
# Now saving tile with title:  images/Normal Lymphnode images/83_1
# Now saving tile with title:  images/Normal Lymphnode images/84_1
# Now saving tile with title:  images/Normal Lymphnode images/85_1
# Now saving tile with title:  images/Normal Lymphnode images/86_1
# Now saving tile with title:  images/Normal Lymphnode images/87_1
# Now saving tile with title:  images/Normal Lymphnode images/88_1
# Now saving tile with title:  images/Normal Lymphnode images/89_1
# Now saving tile with title:  images/Normal Lymphnode images/90_1
# Now saving tile with title:  images/Normal Lymphnode images/91_1
# Now saving tile with title:  images/Normal Lymphnode images/92_1
# Now saving tile with title:  images/Normal Lymphnode images/93_1
# Now saving tile with title:  images/Normal Lymphnode images/94_1
# Now saving tile with title:  images/Normal Lymphnode images/95_1
# Now saving tile with title:  images/Normal Lymphnode images/96_1
# Now saving tile with title:  images/Normal Lymphnode images/97_1
# Now saving tile with title:  images/Normal Lymphnode images/98_1
# Now saving tile with title:  images/Normal Lymphnode images/99_1
# Now saving tile with title:  images/Normal Lymphnode images/100_1
# Now saving tile with title:  images/Normal Lymphnode images/101_1
# Now saving tile with title:  images/Normal Lymphnode images/102_1
# Now saving tile with title:  images/Normal Lymphnode images/103_1
# Now saving tile with title:  images/Normal Lymphnode images/104_1
# Now saving tile with title:  images/Normal Lymphnode images/105_1
# Now saving tile with title:  images/Normal Lymphnode images/106_1
# Now saving tile with title:  images/Normal Lymphnode images/107_1
# Now saving tile with title:  images/Normal Lymphnode images/108_1
# Now saving tile with title:  images/Normal Lymphnode images/109_1
# Now saving tile with title:  images/Normal Lymphnode images/110_1
# Now saving tile with title:  images/Normal Lymphnode images/111_1
# Now saving tile with title:  images/Normal Lymphnode images/112_1
# Now saving tile with title:  images/Normal Lymphnode images/113_1
# Now saving tile with title:  images/Normal Lymphnode images/114_1
# Now saving tile with title:  images/Normal Lymphnode images/115_1
# Now saving tile with title:  images/Normal Lymphnode images/116_1
# Now saving tile with title:  images/Normal Lymphnode images/117_1
# Now saving tile with title:  images/Normal Lymphnode images/118_1
# Now saving tile with title:  images/Normal Lymphnode images/119_1
# Now saving tile with title:  images/Normal Lymphnode images/120_1
# Now saving tile with title:  images/Normal Lymphnode images/121_1
# Now saving tile with title:  images/Normal Lymphnode images/122_1
# Now saving tile with title:  images/Normal Lymphnode images/123_1
# Now saving tile with title:  images/Normal Lymphnode images/124_1
# Now saving tile with title:  images/Normal Lymphnode images/125_1
# Now saving tile with title:  images/Normal Lymphnode images/126_1
# Now saving tile with title:  images/Normal Lymphnode images/127_1
# Now saving tile with title:  images/Normal Lymphnode images/128_1
# Now saving tile with title:  images/Normal Lymphnode images/129_1
# Now saving tile with title:  images/Normal Lymphnode images/130_1
# Now saving tile with title:  images/Normal Lymphnode images/131_1
# Now saving tile with title:  images/Normal Lymphnode images/132_1
# Now saving tile with title:  images/Normal Lymphnode images/133_1
# Now saving tile with title:  images/Normal Lymphnode images/134_1
# Now saving tile with title:  images/Normal Lymphnode images/135_1
# Now saving tile with title:  images/Normal Lymphnode images/136_1
# Now saving tile with title:  images/Normal Lymphnode images/137_1
# Now saving tile with title:  images/Normal Lymphnode images/138_1
# Now saving tile with title:  images/Normal Lymphnode images/139_1
# Now saving tile with title:  images/Normal Lymphnode images/0_2
# Now saving tile with title:  images/Normal Lymphnode images/1_2
# Now saving tile with title:  images/Normal Lymphnode images/2_2
# Now saving tile with title:  images/Normal Lymphnode images/3_2
# Now saving tile with title:  images/Normal Lymphnode images/4_2
# Now saving tile with title:  images/Normal Lymphnode images/5_2
# Now saving tile with title:  images/Normal Lymphnode images/6_2
# Now saving tile with title:  images/Normal Lymphnode images/7_2
# Now saving tile with title:  images/Normal Lymphnode images/8_2
# Now saving tile with title:  images/Normal Lymphnode images/9_2
# Now saving tile with title:  images/Normal Lymphnode images/10_2
# Now saving tile with title:  images/Normal Lymphnode images/11_2
# Now saving tile with title:  images/Normal Lymphnode images/12_2
# Now saving tile with title:  images/Normal Lymphnode images/13_2
# Now saving tile with title:  images/Normal Lymphnode images/14_2
# Now saving tile with title:  images/Normal Lymphnode images/15_2
# Now saving tile with title:  images/Normal Lymphnode images/16_2
# Now saving tile with title:  images/Normal Lymphnode images/17_2
# Now saving tile with title:  images/Normal Lymphnode images/18_2
# Now saving tile with title:  images/Normal Lymphnode images/19_2
# Now saving tile with title:  images/Normal Lymphnode images/20_2
# Now saving tile with title:  images/Normal Lymphnode images/21_2
# Now saving tile with title:  images/Normal Lymphnode images/22_2
# Now saving tile with title:  images/Normal Lymphnode images/23_2
# Now saving tile with title:  images/Normal Lymphnode images/24_2
# Now saving tile with title:  images/Normal Lymphnode images/25_2
# Now saving tile with title:  images/Normal Lymphnode images/26_2
# Now saving tile with title:  images/Normal Lymphnode images/27_2
# Now saving tile with title:  images/Normal Lymphnode images/28_2
# Now saving tile with title:  images/Normal Lymphnode images/29_2
# Now saving tile with title:  images/Normal Lymphnode images/30_2
# Now saving tile with title:  images/Normal Lymphnode images/31_2
# Now saving tile with title:  images/Normal Lymphnode images/32_2
# Now saving tile with title:  images/Normal Lymphnode images/33_2
# Now saving tile with title:  images/Normal Lymphnode images/34_2
# Now saving tile with title:  images/Normal Lymphnode images/35_2
# Now saving tile with title:  images/Normal Lymphnode images/36_2
# Now saving tile with title:  images/Normal Lymphnode images/37_2
# Now saving tile with title:  images/Normal Lymphnode images/38_2
# Now saving tile with title:  images/Normal Lymphnode images/39_2
# Now saving tile with title:  images/Normal Lymphnode images/40_2
# Now saving tile with title:  images/Normal Lymphnode images/41_2
# Now saving tile with title:  images/Normal Lymphnode images/42_2
# Now saving tile with title:  images/Normal Lymphnode images/43_2
# Now saving tile with title:  images/Normal Lymphnode images/44_2
# Now saving tile with title:  images/Normal Lymphnode images/45_2
# Now saving tile with title:  images/Normal Lymphnode images/46_2
# Now saving tile with title:  images/Normal Lymphnode images/47_2
# Now saving tile with title:  images/Normal Lymphnode images/48_2
# Now saving tile with title:  images/Normal Lymphnode images/49_2
# Now saving tile with title:  images/Normal Lymphnode images/50_2
# Now saving tile with title:  images/Normal Lymphnode images/51_2
# Now saving tile with title:  images/Normal Lymphnode images/52_2
# Now saving tile with title:  images/Normal Lymphnode images/53_2
# Now saving tile with title:  images/Normal Lymphnode images/54_2
# Now saving tile with title:  images/Normal Lymphnode images/55_2
# Now saving tile with title:  images/Normal Lymphnode images/56_2
# Now saving tile with title:  images/Normal Lymphnode images/57_2
# Now saving tile with title:  images/Normal Lymphnode images/58_2
# Now saving tile with title:  images/Normal Lymphnode images/59_2
# Now saving tile with title:  images/Normal Lymphnode images/60_2
# Now saving tile with title:  images/Normal Lymphnode images/61_2
# Now saving tile with title:  images/Normal Lymphnode images/62_2
# Now saving tile with title:  images/Normal Lymphnode images/63_2
# Now saving tile with title:  images/Normal Lymphnode images/64_2
# Now saving tile with title:  images/Normal Lymphnode images/65_2
# Now saving tile with title:  images/Normal Lymphnode images/66_2
# Now saving tile with title:  images/Normal Lymphnode images/67_2
# Now saving tile with title:  images/Normal Lymphnode images/68_2
# Now saving tile with title:  images/Normal Lymphnode images/69_2
# Now saving tile with title:  images/Normal Lymphnode images/70_2
# Now saving tile with title:  images/Normal Lymphnode images/71_2
# Now saving tile with title:  images/Normal Lymphnode images/72_2
# Now saving tile with title:  images/Normal Lymphnode images/73_2
# Now saving tile with title:  images/Normal Lymphnode images/74_2
# Now saving tile with title:  images/Normal Lymphnode images/75_2
# Now saving tile with title:  images/Normal Lymphnode images/76_2
# Now saving tile with title:  images/Normal Lymphnode images/77_2
# Now saving tile with title:  images/Normal Lymphnode images/78_2
# Now saving tile with title:  images/Normal Lymphnode images/79_2
# Now saving tile with title:  images/Normal Lymphnode images/80_2
# Now saving tile with title:  images/Normal Lymphnode images/81_2
# Now saving tile with title:  images/Normal Lymphnode images/82_2
# Now saving tile with title:  images/Normal Lymphnode images/83_2
# Now saving tile with title:  images/Normal Lymphnode images/84_2
# Now saving tile with title:  images/Normal Lymphnode images/85_2
# Now saving tile with title:  images/Normal Lymphnode images/86_2
# Now saving tile with title:  images/Normal Lymphnode images/87_2
# Now saving tile with title:  images/Normal Lymphnode images/88_2
# Now saving tile with title:  images/Normal Lymphnode images/89_2
# Now saving tile with title:  images/Normal Lymphnode images/90_2
# Now saving tile with title:  images/Normal Lymphnode images/91_2
# Now saving tile with title:  images/Normal Lymphnode images/92_2
# Now saving tile with title:  images/Normal Lymphnode images/93_2
# Now saving tile with title:  images/Normal Lymphnode images/94_2
# Now saving tile with title:  images/Normal Lymphnode images/95_2
# Now saving tile with title:  images/Normal Lymphnode images/96_2
# Now saving tile with title:  images/Normal Lymphnode images/97_2
# Now saving tile with title:  images/Normal Lymphnode images/98_2
# Now saving tile with title:  images/Normal Lymphnode images/99_2
# Now saving tile with title:  images/Normal Lymphnode images/100_2
# Now saving tile with title:  images/Normal Lymphnode images/101_2
# Now saving tile with title:  images/Normal Lymphnode images/102_2
# Now saving tile with title:  images/Normal Lymphnode images/103_2
# Now saving tile with title:  images/Normal Lymphnode images/104_2
# Now saving tile with title:  images/Normal Lymphnode images/105_2
# Now saving tile with title:  images/Normal Lymphnode images/106_2
# Now saving tile with title:  images/Normal Lymphnode images/107_2
# Now saving tile with title:  images/Normal Lymphnode images/108_2
# Now saving tile with title:  images/Normal Lymphnode images/109_2
# Now saving tile with title:  images/Normal Lymphnode images/110_2
# Now saving tile with title:  images/Normal Lymphnode images/111_2
# Now saving tile with title:  images/Normal Lymphnode images/112_2
# Now saving tile with title:  images/Normal Lymphnode images/113_2
# Now saving tile with title:  images/Normal Lymphnode images/114_2
# Now saving tile with title:  images/Normal Lymphnode images/115_2
# Now saving tile with title:  images/Normal Lymphnode images/116_2
# Now saving tile with title:  images/Normal Lymphnode images/117_2
# Now saving tile with title:  images/Normal Lymphnode images/118_2
# Now saving tile with title:  images/Normal Lymphnode images/119_2
# Now saving tile with title:  images/Normal Lymphnode images/120_2
# Now saving tile with title:  images/Normal Lymphnode images/121_2
# Now saving tile with title:  images/Normal Lymphnode images/122_2
# Now saving tile with title:  images/Normal Lymphnode images/123_2
# Now saving tile with title:  images/Normal Lymphnode images/124_2
# Now saving tile with title:  images/Normal Lymphnode images/125_2
# Now saving tile with title:  images/Normal Lymphnode images/126_2
# Now saving tile with title:  images/Normal Lymphnode images/127_2
# Now saving tile with title:  images/Normal Lymphnode images/128_2
# Now saving tile with title:  images/Normal Lymphnode images/129_2
# Now saving tile with title:  images/Normal Lymphnode images/130_2
# Now saving tile with title:  images/Normal Lymphnode images/131_2
# Now saving tile with title:  images/Normal Lymphnode images/132_2
# Now saving tile with title:  images/Normal Lymphnode images/133_2
# Now saving tile with title:  images/Normal Lymphnode images/134_2
# Now saving tile with title:  images/Normal Lymphnode images/135_2
# Now saving tile with title:  images/Normal Lymphnode images/136_2
# Now saving tile with title:  images/Normal Lymphnode images/137_2
# Now saving tile with title:  images/Normal Lymphnode images/138_2
# Now saving tile with title:  images/Normal Lymphnode images/139_2
# Now saving tile with title:  images/Normal Lymphnode images/0_3
# Now saving tile with title:  images/Normal Lymphnode images/1_3
# Now saving tile with title:  images/Normal Lymphnode images/2_3
# Now saving tile with title:  images/Normal Lymphnode images/3_3
# Now saving tile with title:  images/Normal Lymphnode images/4_3
# Now saving tile with title:  images/Normal Lymphnode images/5_3
# Now saving tile with title:  images/Normal Lymphnode images/6_3
# Now saving tile with title:  images/Normal Lymphnode images/7_3
# Now saving tile with title:  images/Normal Lymphnode images/8_3
# Now saving tile with title:  images/Normal Lymphnode images/9_3
# Now saving tile with title:  images/Normal Lymphnode images/10_3
# Now saving tile with title:  images/Normal Lymphnode images/11_3
# Now saving tile with title:  images/Normal Lymphnode images/12_3
# Now saving tile with title:  images/Normal Lymphnode images/13_3
# Now saving tile with title:  images/Normal Lymphnode images/14_3
# Now saving tile with title:  images/Normal Lymphnode images/15_3
# Now saving tile with title:  images/Normal Lymphnode images/16_3
# Now saving tile with title:  images/Normal Lymphnode images/17_3
# Now saving tile with title:  images/Normal Lymphnode images/18_3
# Now saving tile with title:  images/Normal Lymphnode images/19_3
# Now saving tile with title:  images/Normal Lymphnode images/20_3
# Now saving tile with title:  images/Normal Lymphnode images/21_3
# Now saving tile with title:  images/Normal Lymphnode images/22_3
# Now saving tile with title:  images/Normal Lymphnode images/23_3
# Now saving tile with title:  images/Normal Lymphnode images/24_3
# Now saving tile with title:  images/Normal Lymphnode images/25_3
# Now saving tile with title:  images/Normal Lymphnode images/26_3
# Now saving tile with title:  images/Normal Lymphnode images/27_3
# Now saving tile with title:  images/Normal Lymphnode images/28_3
# Now saving tile with title:  images/Normal Lymphnode images/29_3
# Now saving tile with title:  images/Normal Lymphnode images/30_3
# Now saving tile with title:  images/Normal Lymphnode images/31_3
# Now saving tile with title:  images/Normal Lymphnode images/32_3
# Now saving tile with title:  images/Normal Lymphnode images/33_3
# Now saving tile with title:  images/Normal Lymphnode images/34_3
# Now saving tile with title:  images/Normal Lymphnode images/35_3
# Now saving tile with title:  images/Normal Lymphnode images/36_3
# Now saving tile with title:  images/Normal Lymphnode images/37_3
# Now saving tile with title:  images/Normal Lymphnode images/38_3
# Now saving tile with title:  images/Normal Lymphnode images/39_3
# Now saving tile with title:  images/Normal Lymphnode images/40_3
# Now saving tile with title:  images/Normal Lymphnode images/41_3
# Now saving tile with title:  images/Normal Lymphnode images/42_3
# Now saving tile with title:  images/Normal Lymphnode images/43_3
# Now saving tile with title:  images/Normal Lymphnode images/44_3
# Now saving tile with title:  images/Normal Lymphnode images/45_3
# Now saving tile with title:  images/Normal Lymphnode images/46_3
# Now saving tile with title:  images/Normal Lymphnode images/47_3
# Now saving tile with title:  images/Normal Lymphnode images/48_3
# Now saving tile with title:  images/Normal Lymphnode images/49_3
# Now saving tile with title:  images/Normal Lymphnode images/50_3
# Now saving tile with title:  images/Normal Lymphnode images/51_3
# Now saving tile with title:  images/Normal Lymphnode images/52_3
# Now saving tile with title:  images/Normal Lymphnode images/53_3
# Now saving tile with title:  images/Normal Lymphnode images/54_3
# Now saving tile with title:  images/Normal Lymphnode images/55_3
# Now saving tile with title:  images/Normal Lymphnode images/56_3
# Now saving tile with title:  images/Normal Lymphnode images/57_3
# Now saving tile with title:  images/Normal Lymphnode images/58_3
# Now saving tile with title:  images/Normal Lymphnode images/59_3
# Now saving tile with title:  images/Normal Lymphnode images/60_3
# Now saving tile with title:  images/Normal Lymphnode images/61_3
# Now saving tile with title:  images/Normal Lymphnode images/62_3
# Now saving tile with title:  images/Normal Lymphnode images/63_3
# Now saving tile with title:  images/Normal Lymphnode images/64_3
# Now saving tile with title:  images/Normal Lymphnode images/65_3
# Now saving tile with title:  images/Normal Lymphnode images/66_3
# Now saving tile with title:  images/Normal Lymphnode images/67_3
# Now saving tile with title:  images/Normal Lymphnode images/68_3
# Now saving tile with title:  images/Normal Lymphnode images/69_3
# Now saving tile with title:  images/Normal Lymphnode images/70_3
# Now saving tile with title:  images/Normal Lymphnode images/71_3
# Now saving tile with title:  images/Normal Lymphnode images/72_3
# Now saving tile with title:  images/Normal Lymphnode images/73_3
# Now saving tile with title:  images/Normal Lymphnode images/74_3
# Now saving tile with title:  images/Normal Lymphnode images/75_3
# Now saving tile with title:  images/Normal Lymphnode images/76_3
# Now saving tile with title:  images/Normal Lymphnode images/77_3
# Now saving tile with title:  images/Normal Lymphnode images/78_3
# Now saving tile with title:  images/Normal Lymphnode images/79_3
# Now saving tile with title:  images/Normal Lymphnode images/80_3
# Now saving tile with title:  images/Normal Lymphnode images/81_3
# Now saving tile with title:  images/Normal Lymphnode images/82_3
# Now saving tile with title:  images/Normal Lymphnode images/83_3
# Now saving tile with title:  images/Normal Lymphnode images/84_3
# Now saving tile with title:  images/Normal Lymphnode images/85_3
# Now saving tile with title:  images/Normal Lymphnode images/86_3
# Now saving tile with title:  images/Normal Lymphnode images/87_3
# Now saving tile with title:  images/Normal Lymphnode images/88_3
# Now saving tile with title:  images/Normal Lymphnode images/89_3
# Now saving tile with title:  images/Normal Lymphnode images/90_3
# Now saving tile with title:  images/Normal Lymphnode images/91_3
# Now saving tile with title:  images/Normal Lymphnode images/92_3
# Now saving tile with title:  images/Normal Lymphnode images/93_3
# Now saving tile with title:  images/Normal Lymphnode images/94_3
# Now saving tile with title:  images/Normal Lymphnode images/95_3
# Now saving tile with title:  images/Normal Lymphnode images/96_3
# Now saving tile with title:  images/Normal Lymphnode images/97_3
# Now saving tile with title:  images/Normal Lymphnode images/98_3
# Now saving tile with title:  images/Normal Lymphnode images/99_3
# Now saving tile with title:  images/Normal Lymphnode images/100_3
# Now saving tile with title:  images/Normal Lymphnode images/101_3
# Now saving tile with title:  images/Normal Lymphnode images/102_3
# Now saving tile with title:  images/Normal Lymphnode images/103_3
# Now saving tile with title:  images/Normal Lymphnode images/104_3
# Now saving tile with title:  images/Normal Lymphnode images/105_3
# Now saving tile with title:  images/Normal Lymphnode images/106_3
# Now saving tile with title:  images/Normal Lymphnode images/107_3
# Now saving tile with title:  images/Normal Lymphnode images/108_3
# Now saving tile with title:  images/Normal Lymphnode images/109_3
# Now saving tile with title:  images/Normal Lymphnode images/110_3
# Now saving tile with title:  images/Normal Lymphnode images/111_3
# Now saving tile with title:  images/Normal Lymphnode images/112_3
# Now saving tile with title:  images/Normal Lymphnode images/113_3
# Now saving tile with title:  images/Normal Lymphnode images/114_3
# Now saving tile with title:  images/Normal Lymphnode images/115_3
# Now saving tile with title:  images/Normal Lymphnode images/116_3
# Now saving tile with title:  images/Normal Lymphnode images/117_3
# Now saving tile with title:  images/Normal Lymphnode images/118_3
# Now saving tile with title:  images/Normal Lymphnode images/119_3
# Now saving tile with title:  images/Normal Lymphnode images/120_3
# Now saving tile with title:  images/Normal Lymphnode images/121_3
# Now saving tile with title:  images/Normal Lymphnode images/122_3
# Now saving tile with title:  images/Normal Lymphnode images/123_3
# Now saving tile with title:  images/Normal Lymphnode images/124_3
# Now saving tile with title:  images/Normal Lymphnode images/125_3
# Now saving tile with title:  images/Normal Lymphnode images/126_3
# Now saving tile with title:  images/Normal Lymphnode images/127_3
# Now saving tile with title:  images/Normal Lymphnode images/128_3
# Now saving tile with title:  images/Normal Lymphnode images/129_3
# Now saving tile with title:  images/Normal Lymphnode images/130_3
# Now saving tile with title:  images/Normal Lymphnode images/131_3
# Now saving tile with title:  images/Normal Lymphnode images/132_3
# Now saving tile with title:  images/Normal Lymphnode images/133_3
# Now saving tile with title:  images/Normal Lymphnode images/134_3
# Now saving tile with title:  images/Normal Lymphnode images/135_3
# Now saving tile with title:  images/Normal Lymphnode images/136_3
# Now saving tile with title:  images/Normal Lymphnode images/137_3
# Now saving tile with title:  images/Normal Lymphnode images/138_3
# Now saving tile with title:  images/Normal Lymphnode images/139_3
# Now saving tile with title:  images/Normal Lymphnode images/0_4
# Now saving tile with title:  images/Normal Lymphnode images/1_4
# Now saving tile with title:  images/Normal Lymphnode images/2_4
# Now saving tile with title:  images/Normal Lymphnode images/3_4
# Now saving tile with title:  images/Normal Lymphnode images/4_4
# Now saving tile with title:  images/Normal Lymphnode images/5_4
# Now saving tile with title:  images/Normal Lymphnode images/6_4
# Now saving tile with title:  images/Normal Lymphnode images/7_4
# Now saving tile with title:  images/Normal Lymphnode images/8_4
# Now saving tile with title:  images/Normal Lymphnode images/9_4
# Now saving tile with title:  images/Normal Lymphnode images/10_4
# Now saving tile with title:  images/Normal Lymphnode images/11_4
# Now saving tile with title:  images/Normal Lymphnode images/12_4
# Now saving tile with title:  images/Normal Lymphnode images/13_4
# Now saving tile with title:  images/Normal Lymphnode images/14_4
# Now saving tile with title:  images/Normal Lymphnode images/15_4
# Now saving tile with title:  images/Normal Lymphnode images/16_4
# Now saving tile with title:  images/Normal Lymphnode images/17_4
# Now saving tile with title:  images/Normal Lymphnode images/18_4
# Now saving tile with title:  images/Normal Lymphnode images/19_4
# Now saving tile with title:  images/Normal Lymphnode images/20_4
# Now saving tile with title:  images/Normal Lymphnode images/21_4
# Now saving tile with title:  images/Normal Lymphnode images/22_4
# Now saving tile with title:  images/Normal Lymphnode images/23_4
# Now saving tile with title:  images/Normal Lymphnode images/24_4
# Now saving tile with title:  images/Normal Lymphnode images/25_4
# Now saving tile with title:  images/Normal Lymphnode images/26_4
# Now saving tile with title:  images/Normal Lymphnode images/27_4
# Now saving tile with title:  images/Normal Lymphnode images/28_4
# Now saving tile with title:  images/Normal Lymphnode images/29_4
# Now saving tile with title:  images/Normal Lymphnode images/30_4
# Now saving tile with title:  images/Normal Lymphnode images/31_4
# Now saving tile with title:  images/Normal Lymphnode images/32_4
# Now saving tile with title:  images/Normal Lymphnode images/33_4
# Now saving tile with title:  images/Normal Lymphnode images/34_4
# Now saving tile with title:  images/Normal Lymphnode images/35_4
# Now saving tile with title:  images/Normal Lymphnode images/36_4
# Now saving tile with title:  images/Normal Lymphnode images/37_4
# Now saving tile with title:  images/Normal Lymphnode images/38_4
# Now saving tile with title:  images/Normal Lymphnode images/39_4
# Now saving tile with title:  images/Normal Lymphnode images/40_4
# Now saving tile with title:  images/Normal Lymphnode images/41_4
# Now saving tile with title:  images/Normal Lymphnode images/42_4
# Now saving tile with title:  images/Normal Lymphnode images/43_4
# Now saving tile with title:  images/Normal Lymphnode images/44_4
# Now saving tile with title:  images/Normal Lymphnode images/45_4
# Now saving tile with title:  images/Normal Lymphnode images/46_4
# Now saving tile with title:  images/Normal Lymphnode images/47_4
# Now saving tile with title:  images/Normal Lymphnode images/48_4
# Now saving tile with title:  images/Normal Lymphnode images/49_4
# Now saving tile with title:  images/Normal Lymphnode images/50_4
# Now saving tile with title:  images/Normal Lymphnode images/51_4
# Now saving tile with title:  images/Normal Lymphnode images/52_4
# Now saving tile with title:  images/Normal Lymphnode images/53_4
# Now saving tile with title:  images/Normal Lymphnode images/54_4
# Now saving tile with title:  images/Normal Lymphnode images/55_4
# Now saving tile with title:  images/Normal Lymphnode images/56_4
# Now saving tile with title:  images/Normal Lymphnode images/57_4
# Now saving tile with title:  images/Normal Lymphnode images/58_4
# Now saving tile with title:  images/Normal Lymphnode images/59_4
# Now saving tile with title:  images/Normal Lymphnode images/60_4
# Now saving tile with title:  images/Normal Lymphnode images/61_4
# Now saving tile with title:  images/Normal Lymphnode images/62_4
# Now saving tile with title:  images/Normal Lymphnode images/63_4
# Now saving tile with title:  images/Normal Lymphnode images/64_4
# Now saving tile with title:  images/Normal Lymphnode images/65_4
# Now saving tile with title:  images/Normal Lymphnode images/66_4
# Now saving tile with title:  images/Normal Lymphnode images/67_4
# Now saving tile with title:  images/Normal Lymphnode images/68_4
# Now saving tile with title:  images/Normal Lymphnode images/69_4
# Now saving tile with title:  images/Normal Lymphnode images/70_4
# Now saving tile with title:  images/Normal Lymphnode images/71_4
# Now saving tile with title:  images/Normal Lymphnode images/72_4
# Now saving tile with title:  images/Normal Lymphnode images/73_4
# Now saving tile with title:  images/Normal Lymphnode images/74_4
# Now saving tile with title:  images/Normal Lymphnode images/75_4
# Now saving tile with title:  images/Normal Lymphnode images/76_4
# Now saving tile with title:  images/Normal Lymphnode images/77_4
# Now saving tile with title:  images/Normal Lymphnode images/78_4
# Now saving tile with title:  images/Normal Lymphnode images/79_4
# Now saving tile with title:  images/Normal Lymphnode images/80_4
# Now saving tile with title:  images/Normal Lymphnode images/81_4
# Now saving tile with title:  images/Normal Lymphnode images/82_4
# Now saving tile with title:  images/Normal Lymphnode images/83_4
# Now saving tile with title:  images/Normal Lymphnode images/84_4
# Now saving tile with title:  images/Normal Lymphnode images/85_4
# Now saving tile with title:  images/Normal Lymphnode images/86_4
# Now saving tile with title:  images/Normal Lymphnode images/87_4
# Now saving tile with title:  images/Normal Lymphnode images/88_4
# Now saving tile with title:  images/Normal Lymphnode images/89_4
# Now saving tile with title:  images/Normal Lymphnode images/90_4
# Now saving tile with title:  images/Normal Lymphnode images/91_4
# Now saving tile with title:  images/Normal Lymphnode images/92_4
# Now saving tile with title:  images/Normal Lymphnode images/93_4
# Now saving tile with title:  images/Normal Lymphnode images/94_4
# Now saving tile with title:  images/Normal Lymphnode images/95_4
# Now saving tile with title:  images/Normal Lymphnode images/96_4
# Now saving tile with title:  images/Normal Lymphnode images/97_4
# Now saving tile with title:  images/Normal Lymphnode images/98_4
# Now saving tile with title:  images/Normal Lymphnode images/99_4
# Now saving tile with title:  images/Normal Lymphnode images/100_4
# Now saving tile with title:  images/Normal Lymphnode images/101_4
# Now saving tile with title:  images/Normal Lymphnode images/102_4
# Now saving tile with title:  images/Normal Lymphnode images/103_4
# Now saving tile with title:  images/Normal Lymphnode images/104_4
# Now saving tile with title:  images/Normal Lymphnode images/105_4
# Now saving tile with title:  images/Normal Lymphnode images/106_4
# Now saving tile with title:  images/Normal Lymphnode images/107_4
# Now saving tile with title:  images/Normal Lymphnode images/108_4
# Now saving tile with title:  images/Normal Lymphnode images/109_4
# Now saving tile with title:  images/Normal Lymphnode images/110_4
# Now saving tile with title:  images/Normal Lymphnode images/111_4
# Now saving tile with title:  images/Normal Lymphnode images/112_4
# Now saving tile with title:  images/Normal Lymphnode images/113_4
# Now saving tile with title:  images/Normal Lymphnode images/114_4
# Now saving tile with title:  images/Normal Lymphnode images/115_4
# Now saving tile with title:  images/Normal Lymphnode images/116_4
# Now saving tile with title:  images/Normal Lymphnode images/117_4
# Now saving tile with title:  images/Normal Lymphnode images/118_4
# Now saving tile with title:  images/Normal Lymphnode images/119_4
# Now saving tile with title:  images/Normal Lymphnode images/120_4
# Now saving tile with title:  images/Normal Lymphnode images/121_4
# Now saving tile with title:  images/Normal Lymphnode images/122_4
# Now saving tile with title:  images/Normal Lymphnode images/123_4
# Now saving tile with title:  images/Normal Lymphnode images/124_4
# Now saving tile with title:  images/Normal Lymphnode images/125_4
# Now saving tile with title:  images/Normal Lymphnode images/126_4
# Now saving tile with title:  images/Normal Lymphnode images/127_4
# Now saving tile with title:  images/Normal Lymphnode images/128_4
# Now saving tile with title:  images/Normal Lymphnode images/129_4
# Now saving tile with title:  images/Normal Lymphnode images/130_4
# Now saving tile with title:  images/Normal Lymphnode images/131_4
# Now saving tile with title:  images/Normal Lymphnode images/132_4
# Now saving tile with title:  images/Normal Lymphnode images/133_4
# Now saving tile with title:  images/Normal Lymphnode images/134_4
# Now saving tile with title:  images/Normal Lymphnode images/135_4
# Now saving tile with title:  images/Normal Lymphnode images/136_4
# Now saving tile with title:  images/Normal Lymphnode images/137_4
# Now saving tile with title:  images/Normal Lymphnode images/138_4
# Now saving tile with title:  images/Normal Lymphnode images/139_4
# Now saving tile with title:  images/Normal Lymphnode images/0_5
# Now saving tile with title:  images/Normal Lymphnode images/1_5
# Now saving tile with title:  images/Normal Lymphnode images/2_5
# Now saving tile with title:  images/Normal Lymphnode images/3_5
# Now saving tile with title:  images/Normal Lymphnode images/4_5
# Now saving tile with title:  images/Normal Lymphnode images/5_5
# Now saving tile with title:  images/Normal Lymphnode images/6_5
# Now saving tile with title:  images/Normal Lymphnode images/7_5
# Now saving tile with title:  images/Normal Lymphnode images/8_5
# Now saving tile with title:  images/Normal Lymphnode images/9_5
# Now saving tile with title:  images/Normal Lymphnode images/10_5
# Now saving tile with title:  images/Normal Lymphnode images/11_5
# Now saving tile with title:  images/Normal Lymphnode images/12_5
# Now saving tile with title:  images/Normal Lymphnode images/13_5
# Now saving tile with title:  images/Normal Lymphnode images/14_5
# Now saving tile with title:  images/Normal Lymphnode images/15_5
# Now saving tile with title:  images/Normal Lymphnode images/16_5
# Now saving tile with title:  images/Normal Lymphnode images/17_5
# Now saving tile with title:  images/Normal Lymphnode images/18_5
# Now saving tile with title:  images/Normal Lymphnode images/19_5
# Now saving tile with title:  images/Normal Lymphnode images/20_5
# Now saving tile with title:  images/Normal Lymphnode images/21_5
# Now saving tile with title:  images/Normal Lymphnode images/22_5
# Now saving tile with title:  images/Normal Lymphnode images/23_5
# Now saving tile with title:  images/Normal Lymphnode images/24_5
# Now saving tile with title:  images/Normal Lymphnode images/25_5
# Now saving tile with title:  images/Normal Lymphnode images/26_5
# Now saving tile with title:  images/Normal Lymphnode images/27_5
# Now saving tile with title:  images/Normal Lymphnode images/28_5
# Now saving tile with title:  images/Normal Lymphnode images/29_5
# Now saving tile with title:  images/Normal Lymphnode images/30_5
# Now saving tile with title:  images/Normal Lymphnode images/31_5
# Now saving tile with title:  images/Normal Lymphnode images/32_5
# Now saving tile with title:  images/Normal Lymphnode images/33_5
# Now saving tile with title:  images/Normal Lymphnode images/34_5
# Now saving tile with title:  images/Normal Lymphnode images/35_5
# ...
# Now saving tile with title:  images/Normal Lymphnode images/43_150
# Now saving tile with title:  images/Normal Lymphnode images/44_150
# Now saving tile with title:  images/Normal Lymphnode images/45_150
# Now saving tile with title:  images/Normal Lymphnode images/46_150
# Now saving tile with title:  images/Normal Lymphnode images/47_150
# Now saving tile with title:  images/Normal Lymphnode images/48_150
# Now saving tile with title:  images/Normal Lymphnode images/49_150
# Now saving tile with title:  images/Normal Lymphnode images/50_150
# Now saving tile with title:  images/Normal Lymphnode images/51_150
# Now saving tile with title:  images/Normal Lymphnode images/52_150
# Now saving tile with title:  images/Normal Lymphnode images/53_150
# Now saving tile with title:  images/Normal Lymphnode images/54_150
# Now saving tile with title:  images/Normal Lymphnode images/55_150
# Now saving tile with title:  images/Normal Lymphnode images/56_150
# Now saving tile with title:  images/Normal Lymphnode images/57_150
# Now saving tile with title:  images/Normal Lymphnode images/58_150
# Now saving tile with title:  images/Normal Lymphnode images/59_150
# Now saving tile with title:  images/Normal Lymphnode images/60_150
# Now saving tile with title:  images/Normal Lymphnode images/61_150
# Now saving tile with title:  images/Normal Lymphnode images/62_150
# Now saving tile with title:  images/Normal Lymphnode images/63_150
# Now saving tile with title:  images/Normal Lymphnode images/64_150
# Now saving tile with title:  images/Normal Lymphnode images/65_150
# Now saving tile with title:  images/Normal Lymphnode images/66_150
# Now saving tile with title:  images/Normal Lymphnode images/67_150
# Now saving tile with title:  images/Normal Lymphnode images/68_150
# Now saving tile with title:  images/Normal Lymphnode images/69_150
# Now saving tile with title:  images/Normal Lymphnode images/70_150
# Now saving tile with title:  images/Normal Lymphnode images/71_150
# Now saving tile with title:  images/Normal Lymphnode images/72_150
# Now saving tile with title:  images/Normal Lymphnode images/73_150
# Now saving tile with title:  images/Normal Lymphnode images/74_150
# Now saving tile with title:  images/Normal Lymphnode images/75_150
# Now saving tile with title:  images/Normal Lymphnode images/76_150
# Now saving tile with title:  images/Normal Lymphnode images/77_150
# Now saving tile with title:  images/Normal Lymphnode images/78_150
# Now saving tile with title:  images/Normal Lymphnode images/79_150
# Now saving tile with title:  images/Normal Lymphnode images/80_150
# Now saving tile with title:  images/Normal Lymphnode images/81_150
# Now saving tile with title:  images/Normal Lymphnode images/82_150
# Now saving tile with title:  images/Normal Lymphnode images/83_150
# Now saving tile with title:  images/Normal Lymphnode images/84_150
# Now saving tile with title:  images/Normal Lymphnode images/85_150
# Now saving tile with title:  images/Normal Lymphnode images/86_150
# Now saving tile with title:  images/Normal Lymphnode images/87_150
# Now saving tile with title:  images/Normal Lymphnode images/88_150
# Now saving tile with title:  images/Normal Lymphnode images/89_150
# Now saving tile with title:  images/Normal Lymphnode images/90_150
# Now saving tile with title:  images/Normal Lymphnode images/91_150
# Now saving tile with title:  images/Normal Lymphnode images/92_150
# Now saving tile with title:  images/Normal Lymphnode images/93_150
# Now saving tile with title:  images/Normal Lymphnode images/94_150
# Now saving tile with title:  images/Normal Lymphnode images/95_150
# Now saving tile with title:  images/Normal Lymphnode images/96_150
# Now saving tile with title:  images/Normal Lymphnode images/97_150
# Now saving tile with title:  images/Normal Lymphnode images/98_150
# Now saving tile with title:  images/Normal Lymphnode images/99_150
# Now saving tile with title:  images/Normal Lymphnode images/100_150
# Now saving tile with title:  images/Normal Lymphnode images/101_150
# Now saving tile with title:  images/Normal Lymphnode images/102_150
# Now saving tile with title:  images/Normal Lymphnode images/103_150
# Now saving tile with title:  images/Normal Lymphnode images/104_150
# Now saving tile with title:  images/Normal Lymphnode images/105_150
# Now saving tile with title:  images/Normal Lymphnode images/106_150
# Now saving tile with title:  images/Normal Lymphnode images/107_150
# Now saving tile with title:  images/Normal Lymphnode images/108_150
# Now saving tile with title:  images/Normal Lymphnode images/109_150
# Now saving tile with title:  images/Normal Lymphnode images/110_150
# Now saving tile with title:  images/Normal Lymphnode images/111_150
# Now saving tile with title:  images/Normal Lymphnode images/112_150
# Now saving tile with title:  images/Normal Lymphnode images/113_150
# Now saving tile with title:  images/Normal Lymphnode images/114_150
# Now saving tile with title:  images/Normal Lymphnode images/115_150
# Now saving tile with title:  images/Normal Lymphnode images/116_150
# Now saving tile with title:  images/Normal Lymphnode images/117_150
# Now saving tile with title:  images/Normal Lymphnode images/118_150
# Now saving tile with title:  images/Normal Lymphnode images/119_150
# Now saving tile with title:  images/Normal Lymphnode images/120_150
# Now saving tile with title:  images/Normal Lymphnode images/121_150
# Now saving tile with title:  images/Normal Lymphnode images/122_150
# Now saving tile with title:  images/Normal Lymphnode images/123_150
# Now saving tile with title:  images/Normal Lymphnode images/124_150
# Now saving tile with title:  images/Normal Lymphnode images/125_150
# Now saving tile with title:  images/Normal Lymphnode images/126_150
# Now saving tile with title:  images/Normal Lymphnode images/127_150
# Now saving tile with title:  images/Normal Lymphnode images/128_150
# Now saving tile with title:  images/Normal Lymphnode images/129_150
# Now saving tile with title:  images/Normal Lymphnode images/130_150
# Now saving tile with title:  images/Normal Lymphnode images/131_150
# Now saving tile with title:  images/Normal Lymphnode images/132_150
# Now saving tile with title:  images/Normal Lymphnode images/133_150
# Now saving tile with title:  images/Normal Lymphnode images/134_150
# Now saving tile with title:  images/Normal Lymphnode images/135_150
# Now saving tile with title:  images/Normal Lymphnode images/136_150
# Now saving tile with title:  images/Normal Lymphnode images/137_150
# Now saving tile with title:  images/Normal Lymphnode images/138_150
# Now saving tile with title:  images/Normal Lymphnode images/139_150
# Now saving tile with title:  images/Normal Lymphnode images/0_151
# Now saving tile with title:  images/Normal Lymphnode images/1_151
# Now saving tile with title:  images/Normal Lymphnode images/2_151
# Now saving tile with title:  images/Normal Lymphnode images/3_151
# Now saving tile with title:  images/Normal Lymphnode images/4_151
# Now saving tile with title:  images/Normal Lymphnode images/5_151
# Now saving tile with title:  images/Normal Lymphnode images/6_151
# Now saving tile with title:  images/Normal Lymphnode images/7_151
# Now saving tile with title:  images/Normal Lymphnode images/8_151
# Now saving tile with title:  images/Normal Lymphnode images/9_151
# Now saving tile with title:  images/Normal Lymphnode images/10_151
# Now saving tile with title:  images/Normal Lymphnode images/11_151
# Now saving tile with title:  images/Normal Lymphnode images/12_151
# Now saving tile with title:  images/Normal Lymphnode images/13_151
# Now saving tile with title:  images/Normal Lymphnode images/14_151
# Now saving tile with title:  images/Normal Lymphnode images/15_151
# Now saving tile with title:  images/Normal Lymphnode images/16_151
# Now saving tile with title:  images/Normal Lymphnode images/17_151
# Now saving tile with title:  images/Normal Lymphnode images/18_151
# Now saving tile with title:  images/Normal Lymphnode images/19_151
# Now saving tile with title:  images/Normal Lymphnode images/20_151
# Now saving tile with title:  images/Normal Lymphnode images/21_151
# Now saving tile with title:  images/Normal Lymphnode images/22_151
# Now saving tile with title:  images/Normal Lymphnode images/23_151
# Now saving tile with title:  images/Normal Lymphnode images/24_151
# Now saving tile with title:  images/Normal Lymphnode images/25_151
# Now saving tile with title:  images/Normal Lymphnode images/26_151
# Now saving tile with title:  images/Normal Lymphnode images/27_151
# Now saving tile with title:  images/Normal Lymphnode images/28_151
# Now saving tile with title:  images/Normal Lymphnode images/29_151
# Now saving tile with title:  images/Normal Lymphnode images/30_151
# Now saving tile with title:  images/Normal Lymphnode images/31_151
# Now saving tile with title:  images/Normal Lymphnode images/32_151
# Now saving tile with title:  images/Normal Lymphnode images/33_151
# Now saving tile with title:  images/Normal Lymphnode images/34_151
# Now saving tile with title:  images/Normal Lymphnode images/35_151
# Now saving tile with title:  images/Normal Lymphnode images/36_151
# Now saving tile with title:  images/Normal Lymphnode images/37_151
# Now saving tile with title:  images/Normal Lymphnode images/38_151
# Now saving tile with title:  images/Normal Lymphnode images/39_151
# Now saving tile with title:  images/Normal Lymphnode images/40_151
# Now saving tile with title:  images/Normal Lymphnode images/41_151
# Now saving tile with title:  images/Normal Lymphnode images/42_151
# Now saving tile with title:  images/Normal Lymphnode images/43_151
# Now saving tile with title:  images/Normal Lymphnode images/44_151
# Now saving tile with title:  images/Normal Lymphnode images/45_151
# Now saving tile with title:  images/Normal Lymphnode images/46_151
# Now saving tile with title:  images/Normal Lymphnode images/47_151
# Now saving tile with title:  images/Normal Lymphnode images/48_151
# Now saving tile with title:  images/Normal Lymphnode images/49_151
# Now saving tile with title:  images/Normal Lymphnode images/50_151
# Now saving tile with title:  images/Normal Lymphnode images/51_151
# Now saving tile with title:  images/Normal Lymphnode images/52_151
# Now saving tile with title:  images/Normal Lymphnode images/53_151
# Now saving tile with title:  images/Normal Lymphnode images/54_151
# Now saving tile with title:  images/Normal Lymphnode images/55_151
# Now saving tile with title:  images/Normal Lymphnode images/56_151
# Now saving tile with title:  images/Normal Lymphnode images/57_151
# Now saving tile with title:  images/Normal Lymphnode images/58_151
# Now saving tile with title:  images/Normal Lymphnode images/59_151
# Now saving tile with title:  images/Normal Lymphnode images/60_151
# Now saving tile with title:  images/Normal Lymphnode images/61_151
# Now saving tile with title:  images/Normal Lymphnode images/62_151
# Now saving tile with title:  images/Normal Lymphnode images/63_151
# Now saving tile with title:  images/Normal Lymphnode images/64_151
# Now saving tile with title:  images/Normal Lymphnode images/65_151
# Now saving tile with title:  images/Normal Lymphnode images/66_151
# Now saving tile with title:  images/Normal Lymphnode images/67_151
# Now saving tile with title:  images/Normal Lymphnode images/68_151
# Now saving tile with title:  images/Normal Lymphnode images/69_151
# Now saving tile with title:  images/Normal Lymphnode images/70_151
# Now saving tile with title:  images/Normal Lymphnode images/71_151
# Now saving tile with title:  images/Normal Lymphnode images/72_151
# Now saving tile with title:  images/Normal Lymphnode images/73_151
# Now saving tile with title:  images/Normal Lymphnode images/74_151
# Now saving tile with title:  images/Normal Lymphnode images/75_151
# Now saving tile with title:  images/Normal Lymphnode images/76_151
# Now saving tile with title:  images/Normal Lymphnode images/77_151
# Now saving tile with title:  images/Normal Lymphnode images/78_151
# Now saving tile with title:  images/Normal Lymphnode images/79_151
# Now saving tile with title:  images/Normal Lymphnode images/80_151
# Now saving tile with title:  images/Normal Lymphnode images/81_151
# Now saving tile with title:  images/Normal Lymphnode images/82_151
# Now saving tile with title:  images/Normal Lymphnode images/83_151
# Now saving tile with title:  images/Normal Lymphnode images/84_151
# Now saving tile with title:  images/Normal Lymphnode images/85_151
# Now saving tile with title:  images/Normal Lymphnode images/86_151
# Now saving tile with title:  images/Normal Lymphnode images/87_151
# Now saving tile with title:  images/Normal Lymphnode images/88_151
# Now saving tile with title:  images/Normal Lymphnode images/89_151
# Now saving tile with title:  images/Normal Lymphnode images/90_151
# Now saving tile with title:  images/Normal Lymphnode images/91_151
# Now saving tile with title:  images/Normal Lymphnode images/92_151
# Now saving tile with title:  images/Normal Lymphnode images/93_151
# Now saving tile with title:  images/Normal Lymphnode images/94_151
# Now saving tile with title:  images/Normal Lymphnode images/95_151
# Now saving tile with title:  images/Normal Lymphnode images/96_151
# Now saving tile with title:  images/Normal Lymphnode images/97_151
# Now saving tile with title:  images/Normal Lymphnode images/98_151
# Now saving tile with title:  images/Normal Lymphnode images/99_151
# Now saving tile with title:  images/Normal Lymphnode images/100_151
# Now saving tile with title:  images/Normal Lymphnode images/101_151
# Now saving tile with title:  images/Normal Lymphnode images/102_151
# Now saving tile with title:  images/Normal Lymphnode images/103_151
# Now saving tile with title:  images/Normal Lymphnode images/104_151
# Now saving tile with title:  images/Normal Lymphnode images/105_151
# Now saving tile with title:  images/Normal Lymphnode images/106_151
# Now saving tile with title:  images/Normal Lymphnode images/107_151
# Now saving tile with title:  images/Normal Lymphnode images/108_151
# Now saving tile with title:  images/Normal Lymphnode images/109_151
# Now saving tile with title:  images/Normal Lymphnode images/110_151
# Now saving tile with title:  images/Normal Lymphnode images/111_151
# Now saving tile with title:  images/Normal Lymphnode images/112_151
# Now saving tile with title:  images/Normal Lymphnode images/113_151
# Now saving tile with title:  images/Normal Lymphnode images/114_151
# Now saving tile with title:  images/Normal Lymphnode images/115_151
# Now saving tile with title:  images/Normal Lymphnode images/116_151
# Now saving tile with title:  images/Normal Lymphnode images/117_151
# Now saving tile with title:  images/Normal Lymphnode images/118_151
# Now saving tile with title:  images/Normal Lymphnode images/119_151
# Now saving tile with title:  images/Normal Lymphnode images/120_151
# Now saving tile with title:  images/Normal Lymphnode images/121_151
# Now saving tile with title:  images/Normal Lymphnode images/122_151
# Now saving tile with title:  images/Normal Lymphnode images/123_151
# Now saving tile with title:  images/Normal Lymphnode images/124_151
# Now saving tile with title:  images/Normal Lymphnode images/125_151
# Now saving tile with title:  images/Normal Lymphnode images/126_151
# Now saving tile with title:  images/Normal Lymphnode images/127_151
# Now saving tile with title:  images/Normal Lymphnode images/128_151
# Now saving tile with title:  images/Normal Lymphnode images/129_151
# Now saving tile with title:  images/Normal Lymphnode images/130_151
# Now saving tile with title:  images/Normal Lymphnode images/131_151
# Now saving tile with title:  images/Normal Lymphnode images/132_151
# Now saving tile with title:  images/Normal Lymphnode images/133_151
# Now saving tile with title:  images/Normal Lymphnode images/134_151
# Now saving tile with title:  images/Normal Lymphnode images/135_151
# Now saving tile with title:  images/Normal Lymphnode images/136_151
# Now saving tile with title:  images/Normal Lymphnode images/137_151
# Now saving tile with title:  images/Normal Lymphnode images/138_151
# Now saving tile with title:  images/Normal Lymphnode images/139_151

# %% [markdown]
# ## preprocessing all the images from saved data folder and take only normalized image and save in another folder.

# %%
from normalize_HnE import norm_HnE

# %%
orig_tile_dir_name = "images/Normal Lymphnode images/"
norm_tile_dir_name = "images/Normal Lymphnode images/normalized_tiles/"

# %%
for row in range(rows):
    for col in range(cols):
        tile_name = str(col) + "_" + str(row)
        #tile_name = os.path.join(tile_dir, '%d_%d' % (col, row))
        #print("Now processing tile with title: ", tile_name)
        temp_tile = tiles.get_tile(16, (col, row))
        temp_tile_RGB = temp_tile.convert('RGB')
        temp_tile_np = np.array(temp_tile_RGB)
        #Save original tile
        #tiff.imsave(orig_tile_dir_name+tile_name + "_original.tif", temp_tile_np)
        
        if temp_tile_np.mean() < 230 and temp_tile_np.std() > 15:
            print("Processing tile number:", tile_name)
            norm_img, H_img, E_img = norm_HnE(temp_tile_np, Io=240, alpha=1, beta=0.15)
        #Save the norm tile, H and E tiles      
            
            plt.imsave(norm_tile_dir_name+tile_name + "_norm.png", norm_img)
            #tiff.imsave(H_tile_dir_name+tile_name + "_H.tif", H_img)
            #tiff.imsave(E_tile_dir_name+tile_name + "_E.tif", E_img)
            
        else:
            print("NOT PROCESSING TILE:", tile_name)
# Out:
# NOT PROCESSING TILE: 0_0
# NOT PROCESSING TILE: 1_0
# NOT PROCESSING TILE: 2_0
# NOT PROCESSING TILE: 3_0
# NOT PROCESSING TILE: 4_0
# NOT PROCESSING TILE: 5_0
# NOT PROCESSING TILE: 6_0
# NOT PROCESSING TILE: 7_0
# NOT PROCESSING TILE: 8_0
# NOT PROCESSING TILE: 9_0
# NOT PROCESSING TILE: 10_0
# NOT PROCESSING TILE: 11_0
# NOT PROCESSING TILE: 12_0
# NOT PROCESSING TILE: 13_0
# NOT PROCESSING TILE: 14_0
# NOT PROCESSING TILE: 15_0
# NOT PROCESSING TILE: 16_0
# NOT PROCESSING TILE: 17_0
# NOT PROCESSING TILE: 18_0
# NOT PROCESSING TILE: 19_0
# NOT PROCESSING TILE: 20_0
# NOT PROCESSING TILE: 21_0
# NOT PROCESSING TILE: 22_0
# NOT PROCESSING TILE: 23_0
# NOT PROCESSING TILE: 24_0
# NOT PROCESSING TILE: 25_0
# NOT PROCESSING TILE: 26_0
# NOT PROCESSING TILE: 27_0
# NOT PROCESSING TILE: 28_0
# NOT PROCESSING TILE: 29_0
# NOT PROCESSING TILE: 30_0
# NOT PROCESSING TILE: 31_0
# NOT PROCESSING TILE: 32_0
# NOT PROCESSING TILE: 33_0
# NOT PROCESSING TILE: 34_0
# NOT PROCESSING TILE: 35_0
# NOT PROCESSING TILE: 36_0
# NOT PROCESSING TILE: 37_0
# NOT PROCESSING TILE: 38_0
# NOT PROCESSING TILE: 39_0
# NOT PROCESSING TILE: 40_0
# NOT PROCESSING TILE: 41_0
# NOT PROCESSING TILE: 42_0
# NOT PROCESSING TILE: 43_0
# NOT PROCESSING TILE: 44_0
# NOT PROCESSING TILE: 45_0
# NOT PROCESSING TILE: 46_0
# NOT PROCESSING TILE: 47_0
# NOT PROCESSING TILE: 48_0
# NOT PROCESSING TILE: 49_0
# NOT PROCESSING TILE: 50_0
# NOT PROCESSING TILE: 51_0
# NOT PROCESSING TILE: 52_0
# NOT PROCESSING TILE: 53_0
# NOT PROCESSING TILE: 54_0
# NOT PROCESSING TILE: 55_0
# NOT PROCESSING TILE: 56_0
# NOT PROCESSING TILE: 57_0
# NOT PROCESSING TILE: 58_0
# NOT PROCESSING TILE: 59_0
# NOT PROCESSING TILE: 60_0
# NOT PROCESSING TILE: 61_0
# NOT PROCESSING TILE: 62_0
# NOT PROCESSING TILE: 63_0
# NOT PROCESSING TILE: 64_0
# NOT PROCESSING TILE: 65_0
# NOT PROCESSING TILE: 66_0
# NOT PROCESSING TILE: 67_0
# NOT PROCESSING TILE: 68_0
# NOT PROCESSING TILE: 69_0
# NOT PROCESSING TILE: 70_0
# NOT PROCESSING TILE: 71_0
# NOT PROCESSING TILE: 72_0
# NOT PROCESSING TILE: 73_0
# NOT PROCESSING TILE: 74_0
# NOT PROCESSING TILE: 75_0
# NOT PROCESSING TILE: 76_0
# NOT PROCESSING TILE: 77_0
# NOT PROCESSING TILE: 78_0
# NOT PROCESSING TILE: 79_0
# NOT PROCESSING TILE: 80_0
# NOT PROCESSING TILE: 81_0
# NOT PROCESSING TILE: 82_0
# NOT PROCESSING TILE: 83_0
# NOT PROCESSING TILE: 84_0
# NOT PROCESSING TILE: 85_0
# NOT PROCESSING TILE: 86_0
# NOT PROCESSING TILE: 87_0
# NOT PROCESSING TILE: 88_0
# NOT PROCESSING TILE: 89_0
# NOT PROCESSING TILE: 90_0
# NOT PROCESSING TILE: 91_0
# NOT PROCESSING TILE: 92_0
# NOT PROCESSING TILE: 93_0
# NOT PROCESSING TILE: 94_0
# NOT PROCESSING TILE: 95_0
# NOT PROCESSING TILE: 96_0
# NOT PROCESSING TILE: 97_0
# NOT PROCESSING TILE: 98_0
# NOT PROCESSING TILE: 99_0
# NOT PROCESSING TILE: 100_0
# NOT PROCESSING TILE: 101_0
# NOT PROCESSING TILE: 102_0
# NOT PROCESSING TILE: 103_0
# NOT PROCESSING TILE: 104_0
# NOT PROCESSING TILE: 105_0
# NOT PROCESSING TILE: 106_0
# NOT PROCESSING TILE: 107_0
# NOT PROCESSING TILE: 108_0
# NOT PROCESSING TILE: 109_0
# NOT PROCESSING TILE: 110_0
# NOT PROCESSING TILE: 111_0
# NOT PROCESSING TILE: 112_0
# NOT PROCESSING TILE: 113_0
# NOT PROCESSING TILE: 114_0
# NOT PROCESSING TILE: 115_0
# NOT PROCESSING TILE: 116_0
# NOT PROCESSING TILE: 117_0
# NOT PROCESSING TILE: 118_0
# NOT PROCESSING TILE: 119_0
# NOT PROCESSING TILE: 120_0
# NOT PROCESSING TILE: 121_0
# NOT PROCESSING TILE: 122_0
# NOT PROCESSING TILE: 123_0
# NOT PROCESSING TILE: 124_0
# NOT PROCESSING TILE: 125_0
# NOT PROCESSING TILE: 126_0
# NOT PROCESSING TILE: 127_0
# NOT PROCESSING TILE: 128_0
# NOT PROCESSING TILE: 129_0
# NOT PROCESSING TILE: 130_0
# NOT PROCESSING TILE: 131_0
# NOT PROCESSING TILE: 132_0
# NOT PROCESSING TILE: 133_0
# NOT PROCESSING TILE: 134_0
# NOT PROCESSING TILE: 135_0
# NOT PROCESSING TILE: 136_0
# NOT PROCESSING TILE: 137_0
# NOT PROCESSING TILE: 138_0
# NOT PROCESSING TILE: 139_0
# NOT PROCESSING TILE: 0_1
# NOT PROCESSING TILE: 1_1
# NOT PROCESSING TILE: 2_1
# NOT PROCESSING TILE: 3_1
# NOT PROCESSING TILE: 4_1
# NOT PROCESSING TILE: 5_1
# NOT PROCESSING TILE: 6_1
# NOT PROCESSING TILE: 7_1
# NOT PROCESSING TILE: 8_1
# NOT PROCESSING TILE: 9_1
# NOT PROCESSING TILE: 10_1
# NOT PROCESSING TILE: 11_1
# NOT PROCESSING TILE: 12_1
# NOT PROCESSING TILE: 13_1
# NOT PROCESSING TILE: 14_1
# NOT PROCESSING TILE: 15_1
# NOT PROCESSING TILE: 16_1
# NOT PROCESSING TILE: 17_1
# NOT PROCESSING TILE: 18_1
# NOT PROCESSING TILE: 19_1
# NOT PROCESSING TILE: 20_1
# NOT PROCESSING TILE: 21_1
# NOT PROCESSING TILE: 22_1
# NOT PROCESSING TILE: 23_1
# NOT PROCESSING TILE: 24_1
# NOT PROCESSING TILE: 25_1
# NOT PROCESSING TILE: 26_1
# NOT PROCESSING TILE: 27_1
# NOT PROCESSING TILE: 28_1
# NOT PROCESSING TILE: 29_1
# NOT PROCESSING TILE: 30_1
# NOT PROCESSING TILE: 31_1
# NOT PROCESSING TILE: 32_1
# NOT PROCESSING TILE: 33_1
# NOT PROCESSING TILE: 34_1
# NOT PROCESSING TILE: 35_1
# NOT PROCESSING TILE: 36_1
# NOT PROCESSING TILE: 37_1
# NOT PROCESSING TILE: 38_1
# NOT PROCESSING TILE: 39_1
# NOT PROCESSING TILE: 40_1
# NOT PROCESSING TILE: 41_1
# NOT PROCESSING TILE: 42_1
# NOT PROCESSING TILE: 43_1
# NOT PROCESSING TILE: 44_1
# NOT PROCESSING TILE: 45_1
# NOT PROCESSING TILE: 46_1
# NOT PROCESSING TILE: 47_1
# NOT PROCESSING TILE: 48_1
# NOT PROCESSING TILE: 49_1
# NOT PROCESSING TILE: 50_1
# NOT PROCESSING TILE: 51_1
# NOT PROCESSING TILE: 52_1
# NOT PROCESSING TILE: 53_1
# NOT PROCESSING TILE: 54_1
# NOT PROCESSING TILE: 55_1
# NOT PROCESSING TILE: 56_1
# NOT PROCESSING TILE: 57_1
# NOT PROCESSING TILE: 58_1
# NOT PROCESSING TILE: 59_1
# NOT PROCESSING TILE: 60_1
# NOT PROCESSING TILE: 61_1
# NOT PROCESSING TILE: 62_1
# NOT PROCESSING TILE: 63_1
# NOT PROCESSING TILE: 64_1
# NOT PROCESSING TILE: 65_1
# NOT PROCESSING TILE: 66_1
# NOT PROCESSING TILE: 67_1
# NOT PROCESSING TILE: 68_1
# NOT PROCESSING TILE: 69_1
# NOT PROCESSING TILE: 70_1
# NOT PROCESSING TILE: 71_1
# NOT PROCESSING TILE: 72_1
# NOT PROCESSING TILE: 73_1
# NOT PROCESSING TILE: 74_1
# NOT PROCESSING TILE: 75_1
# NOT PROCESSING TILE: 76_1
# NOT PROCESSING TILE: 77_1
# NOT PROCESSING TILE: 78_1
# NOT PROCESSING TILE: 79_1
# NOT PROCESSING TILE: 80_1
# NOT PROCESSING TILE: 81_1
# NOT PROCESSING TILE: 82_1
# NOT PROCESSING TILE: 83_1
# NOT PROCESSING TILE: 84_1
# NOT PROCESSING TILE: 85_1
# NOT PROCESSING TILE: 86_1
# NOT PROCESSING TILE: 87_1
# NOT PROCESSING TILE: 88_1
# NOT PROCESSING TILE: 89_1
# NOT PROCESSING TILE: 90_1
# NOT PROCESSING TILE: 91_1
# NOT PROCESSING TILE: 92_1
# NOT PROCESSING TILE: 93_1
# NOT PROCESSING TILE: 94_1
# NOT PROCESSING TILE: 95_1
# NOT PROCESSING TILE: 96_1
# NOT PROCESSING TILE: 97_1
# NOT PROCESSING TILE: 98_1
# NOT PROCESSING TILE: 99_1
# NOT PROCESSING TILE: 100_1
# NOT PROCESSING TILE: 101_1
# NOT PROCESSING TILE: 102_1
# NOT PROCESSING TILE: 103_1
# NOT PROCESSING TILE: 104_1
# NOT PROCESSING TILE: 105_1
# NOT PROCESSING TILE: 106_1
# NOT PROCESSING TILE: 107_1
# NOT PROCESSING TILE: 108_1
# NOT PROCESSING TILE: 109_1
# NOT PROCESSING TILE: 110_1
# NOT PROCESSING TILE: 111_1
# NOT PROCESSING TILE: 112_1
# NOT PROCESSING TILE: 113_1
# NOT PROCESSING TILE: 114_1
# NOT PROCESSING TILE: 115_1
# NOT PROCESSING TILE: 116_1
# NOT PROCESSING TILE: 117_1
# NOT PROCESSING TILE: 118_1
# NOT PROCESSING TILE: 119_1
# NOT PROCESSING TILE: 120_1
# NOT PROCESSING TILE: 121_1
# NOT PROCESSING TILE: 122_1
# NOT PROCESSING TILE: 123_1
# NOT PROCESSING TILE: 124_1
# NOT PROCESSING TILE: 125_1
# NOT PROCESSING TILE: 126_1
# NOT PROCESSING TILE: 127_1
# NOT PROCESSING TILE: 128_1
# NOT PROCESSING TILE: 129_1
# NOT PROCESSING TILE: 130_1
# NOT PROCESSING TILE: 131_1
# NOT PROCESSING TILE: 132_1
# NOT PROCESSING TILE: 133_1
# NOT PROCESSING TILE: 134_1
# NOT PROCESSING TILE: 135_1
# NOT PROCESSING TILE: 136_1
# NOT PROCESSING TILE: 137_1
# NOT PROCESSING TILE: 138_1
# NOT PROCESSING TILE: 139_1
# NOT PROCESSING TILE: 0_2
# NOT PROCESSING TILE: 1_2
# NOT PROCESSING TILE: 2_2
# NOT PROCESSING TILE: 3_2
# NOT PROCESSING TILE: 4_2
# NOT PROCESSING TILE: 5_2
# NOT PROCESSING TILE: 6_2
# NOT PROCESSING TILE: 7_2
# NOT PROCESSING TILE: 8_2
# NOT PROCESSING TILE: 9_2
# NOT PROCESSING TILE: 10_2
# NOT PROCESSING TILE: 11_2
# NOT PROCESSING TILE: 12_2
# NOT PROCESSING TILE: 13_2
# NOT PROCESSING TILE: 14_2
# NOT PROCESSING TILE: 15_2
# NOT PROCESSING TILE: 16_2
# NOT PROCESSING TILE: 17_2
# NOT PROCESSING TILE: 18_2
# NOT PROCESSING TILE: 19_2
# NOT PROCESSING TILE: 20_2
# NOT PROCESSING TILE: 21_2
# NOT PROCESSING TILE: 22_2
# NOT PROCESSING TILE: 23_2
# NOT PROCESSING TILE: 24_2
# NOT PROCESSING TILE: 25_2
# NOT PROCESSING TILE: 26_2
# NOT PROCESSING TILE: 27_2
# NOT PROCESSING TILE: 28_2
# NOT PROCESSING TILE: 29_2
# NOT PROCESSING TILE: 30_2
# NOT PROCESSING TILE: 31_2
# NOT PROCESSING TILE: 32_2
# NOT PROCESSING TILE: 33_2
# NOT PROCESSING TILE: 34_2
# NOT PROCESSING TILE: 35_2
# NOT PROCESSING TILE: 36_2
# NOT PROCESSING TILE: 37_2
# NOT PROCESSING TILE: 38_2
# NOT PROCESSING TILE: 39_2
# NOT PROCESSING TILE: 40_2
# NOT PROCESSING TILE: 41_2
# NOT PROCESSING TILE: 42_2
# NOT PROCESSING TILE: 43_2
# NOT PROCESSING TILE: 44_2
# NOT PROCESSING TILE: 45_2
# NOT PROCESSING TILE: 46_2
# NOT PROCESSING TILE: 47_2
# NOT PROCESSING TILE: 48_2
# NOT PROCESSING TILE: 49_2
# NOT PROCESSING TILE: 50_2
# NOT PROCESSING TILE: 51_2
# NOT PROCESSING TILE: 52_2
# NOT PROCESSING TILE: 53_2
# NOT PROCESSING TILE: 54_2
# NOT PROCESSING TILE: 55_2
# NOT PROCESSING TILE: 56_2
# NOT PROCESSING TILE: 57_2
# NOT PROCESSING TILE: 58_2
# NOT PROCESSING TILE: 59_2
# NOT PROCESSING TILE: 60_2
# NOT PROCESSING TILE: 61_2
# NOT PROCESSING TILE: 62_2
# NOT PROCESSING TILE: 63_2
# NOT PROCESSING TILE: 64_2
# NOT PROCESSING TILE: 65_2
# NOT PROCESSING TILE: 66_2
# NOT PROCESSING TILE: 67_2
# NOT PROCESSING TILE: 68_2
# NOT PROCESSING TILE: 69_2
# NOT PROCESSING TILE: 70_2
# NOT PROCESSING TILE: 71_2
# NOT PROCESSING TILE: 72_2
# NOT PROCESSING TILE: 73_2
# NOT PROCESSING TILE: 74_2
# NOT PROCESSING TILE: 75_2
# NOT PROCESSING TILE: 76_2
# NOT PROCESSING TILE: 77_2
# NOT PROCESSING TILE: 78_2
# NOT PROCESSING TILE: 79_2
# NOT PROCESSING TILE: 80_2
# NOT PROCESSING TILE: 81_2
# NOT PROCESSING TILE: 82_2
# NOT PROCESSING TILE: 83_2
# NOT PROCESSING TILE: 84_2
# Processing tile number: 85_2
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10532/339138423.py in <module>
#      12         if temp_tile_np.mean() < 230 and temp_tile_np.std() > 15:
#      13             print("Processing tile number:", tile_name)
# ---> 14             norm_img, H_img, E_img = norm_HnE(temp_tile_np, Io=40, alpha=1, beta=0.15)
#      15         #Save the norm tile, H and E tiles
#      16
#
# ~\Desktop\jupyter\intership assignments\softsensor\normalize_HnE.py in norm_HnE(img, Io, alpha, beta)
#      91     #Estimate covariance matrix of ODhat (transposed)
#      92     # and then compute eigen values & eigenvectors.
# ---> 93     eigvals, eigvecs = np.linalg.eigh(np.cov(ODhat.T))
#      94
#      95
#
# <__array_function__ internals> in eigh(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py in eigh(a, UPLO)
#    1468
#    1469     signature = 'D->dD' if isComplexType(t) else 'd->dd'
# -> 1470     w, vt = gufunc(a, signature=signature, extobj=extobj)
#    1471     w = w.astype(_realType(result_t), copy=False)
#    1472     vt = vt.astype(result_t, copy=False)
#
# ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_eigenvalues_nonconvergence(err, flag)
#      92
#      93 def _raise_linalgerror_eigenvalues_nonconvergence(err, flag):
# ---> 94     raise LinAlgError("Eigenvalues did not converge")
#      95
#      96 def _raise_linalgerror_svd_nonconvergence(err, flag):
#
# LinAlgError: Eigenvalues did not converge
